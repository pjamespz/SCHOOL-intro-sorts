# %% [markdown]
# ## Plotting and Descriptive Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

tr_df = pd.read_csv('uniform_results.csv')
as_df = pd.read_csv('almost_sorted_results.csv')

# %% [markdown]
# ### MergeSort Time Analysis

# %%
merge_tr_1000 = tr_df[(tr_df['Algorithm'] == 'MergeSort') & (tr_df['Data Size'] == 1000)]
merge_tr_2000 = tr_df[(tr_df['Algorithm'] == 'MergeSort') & (tr_df['Data Size'] == 2000)]
merge_tr_4000 = tr_df[(tr_df['Algorithm'] == 'MergeSort') & (tr_df['Data Size'] == 4000)]
merge_tr_8000 = tr_df[(tr_df['Algorithm'] == 'MergeSort') & (tr_df['Data Size'] == 8000)]
merge_tr_16000 = tr_df[(tr_df['Algorithm'] == 'MergeSort') & (tr_df['Data Size'] == 16000)]

merge_as_1000 = as_df[(as_df['Algorithm'] == 'MergeSort') & (as_df['Data Size'] == 1000)]
merge_as_2000 = as_df[(as_df['Algorithm'] == 'MergeSort') & (as_df['Data Size'] == 2000)]
merge_as_4000 = as_df[(as_df['Algorithm'] == 'MergeSort') & (as_df['Data Size'] == 4000)]
merge_as_8000 = as_df[(as_df['Algorithm'] == 'MergeSort') & (as_df['Data Size'] == 8000)]
merge_as_16000 = as_df[(as_df['Algorithm'] == 'MergeSort') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### MergeSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("MergeSort Statistics on True Random Data")
merge_sort_tr = tr_df[tr_df['Algorithm'] == 'MergeSort']
merge_tr_stats = merge_sort_tr.groupby('Data Size').describe()
merge_tr_stats.drop(columns='Theoretical Big-O', inplace=True)
merge_tr_stats.reset_index(inplace=True)
merge_tr_stats.columns = merge_tr_stats.columns.map(' '.join)
merge_tr_stats = pd.DataFrame(merge_tr_stats)
print(merge_tr_stats, '\n')

print("MergeSort Statistics on Almost Sorted Data")
merge_sort_as = as_df[as_df['Algorithm'] == 'MergeSort']
merge_as_stats = merge_sort_as.groupby('Data Size').describe()
merge_as_stats.drop(columns='Theoretical Big-O', inplace=True)
merge_as_stats.reset_index(inplace=True)
merge_as_stats.columns = merge_as_stats.columns.map(' '.join)
merge_as_stats = pd.DataFrame(merge_as_stats)
print(merge_as_stats)
# Out:
# MergeSort Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.001358     0.000023     0.001339     0.001347     0.001351     0.001356     0.001398
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.002968     0.000034     0.002927     0.002948     0.002960     0.002997     0.003008
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.006353     0.000085     0.006291     0.006298     0.006312     0.006374     0.006493
# ...

# %% [markdown]
# #### Plotting MergeSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(merge_tr_1000)), merge_tr_1000['Runtime'], color="orange")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.04)
axs[0].grid(True)

axs[1].bar(range(len(merge_tr_2000)), merge_tr_2000['Runtime'], color="orange")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.04)
axs[1].grid(True)

axs[2].bar(range(len(merge_tr_4000)), merge_tr_4000['Runtime'], color="orange")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.04)
axs[2].grid(True)

axs[3].bar(range(len(merge_tr_8000)), merge_tr_8000['Runtime'], color="orange")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.04)
axs[3].grid(True)

axs[4].bar(range(len(merge_tr_16000)), merge_tr_16000['Runtime'], color="orange")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.04)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("MergeSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 

plt.savefig("mergetr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(merge_as_1000)), merge_as_1000['Runtime'], color="orange")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.04)
axs[0].grid(True)

axs[1].bar(range(len(merge_as_2000)), merge_as_2000['Runtime'], color="orange")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.04)
axs[1].grid(True)

axs[2].bar(range(len(merge_as_4000)), merge_as_4000['Runtime'], color="orange")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.04)
axs[2].grid(True)

axs[3].bar(range(len(merge_as_8000)), merge_as_8000['Runtime'], color="orange")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.04)
axs[3].grid(True)

axs[4].bar(range(len(merge_as_16000)), merge_as_16000['Runtime'], color="orange")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.04)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("MergeSort on Almost-sorted Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 

plt.savefig("mergeas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
merge_tr_runtime = []
merge_as_runtime = []

working_mean = 0

merge_tr_runtime.append(merge_tr_1000['Runtime'].mean())
merge_tr_runtime.append(merge_tr_2000['Runtime'].mean())
merge_tr_runtime.append(merge_tr_4000['Runtime'].mean())
merge_tr_runtime.append(merge_tr_8000['Runtime'].mean())
merge_tr_runtime.append(merge_tr_16000['Runtime'].mean())

merge_as_runtime.append(merge_as_1000['Runtime'].mean())
merge_as_runtime.append(merge_as_2000['Runtime'].mean())
merge_as_runtime.append(merge_as_4000['Runtime'].mean())
merge_as_runtime.append(merge_as_8000['Runtime'].mean())
merge_as_runtime.append(merge_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, merge_tr_runtime, label='Merge TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, merge_as_runtime, label='Merge AS runtime', marker='o')

# Adding titles and labels
plt.title('Mergesort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("mergerun.png")
# Display the plot
plt.show()

# %% [markdown]
# ### QuickSort Time Analysis

# %%
quick_tr_1000 = tr_df[(tr_df['Algorithm'] == 'QuickSort') & (tr_df['Data Size'] == 1000)]
quick_tr_2000 = tr_df[(tr_df['Algorithm'] == 'QuickSort') & (tr_df['Data Size'] == 2000)]
quick_tr_4000 = tr_df[(tr_df['Algorithm'] == 'QuickSort') & (tr_df['Data Size'] == 4000)]
quick_tr_8000 = tr_df[(tr_df['Algorithm'] == 'QuickSort') & (tr_df['Data Size'] == 8000)]
quick_tr_16000 = tr_df[(tr_df['Algorithm'] == 'QuickSort') & (tr_df['Data Size'] == 16000)]

quick_as_1000 = as_df[(as_df['Algorithm'] == 'QuickSort') & (as_df['Data Size'] == 1000)]
quick_as_2000 = as_df[(as_df['Algorithm'] == 'QuickSort') & (as_df['Data Size'] == 2000)]
quick_as_4000 = as_df[(as_df['Algorithm'] == 'QuickSort') & (as_df['Data Size'] == 4000)]
quick_as_8000 = as_df[(as_df['Algorithm'] == 'QuickSort') & (as_df['Data Size'] == 8000)]
quick_as_16000 = as_df[(as_df['Algorithm'] == 'QuickSort') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### QuickSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("QuickSort Statistics on True Random Data")
quick_sort_tr = tr_df[tr_df['Algorithm'] == 'QuickSort']
quick_tr_stats = quick_sort_tr.groupby('Data Size').describe()
quick_tr_stats.drop(columns='Theoretical Big-O', inplace=True)
quick_tr_stats.reset_index(inplace=True)
quick_tr_stats.columns = quick_tr_stats.columns.map(' '.join)
quick_tr_stats = pd.DataFrame(quick_tr_stats)
print(quick_tr_stats, '\n')

print("QuickSort Statistics on Almost Sorted Data")
quick_sort_as = as_df[as_df['Algorithm'] == 'QuickSort']
quick_as_stats = quick_sort_as.groupby('Data Size').describe()
quick_as_stats.drop(columns='Theoretical Big-O', inplace=True)
quick_as_stats.reset_index(inplace=True)
quick_as_stats.columns = quick_as_stats.columns.map(' '.join)
quick_as_stats = pd.DataFrame(quick_as_stats)
print(quick_as_stats)
# Out:
# QuickSort Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.000983     0.000061     0.000915     0.000938     0.000979     0.001017     0.001067
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.002183     0.000095     0.002091     0.002116     0.002166     0.002215     0.002329
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.004996     0.000105     0.004850     0.004967     0.004978     0.005054     0.005132
# ...

# %% [markdown]
# #### Plotting QuickSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(quick_tr_1000)), quick_tr_1000['Runtime'], color="blue")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.05)
axs[0].grid(True)

axs[1].bar(range(len(quick_tr_2000)), quick_tr_2000['Runtime'], color="blue")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.05)
axs[1].grid(True)

axs[2].bar(range(len(quick_tr_4000)), quick_tr_4000['Runtime'], color="blue")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.05)
axs[2].grid(True)

axs[3].bar(range(len(quick_tr_8000)), quick_tr_8000['Runtime'], color="blue")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.05)
axs[3].grid(True)

axs[4].bar(range(len(quick_tr_16000)), quick_tr_16000['Runtime'], color="blue")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.05)
axs[4].grid(True)


fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("Quicksort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("quicktr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(quick_as_1000)), quick_as_1000['Runtime'], color="blue")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.05)
axs[0].grid(True)

axs[1].bar(range(len(quick_as_2000)), quick_as_2000['Runtime'], color="blue")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.05)
axs[1].grid(True)

axs[2].bar(range(len(quick_as_4000)), quick_as_4000['Runtime'], color="blue")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.05)
axs[2].grid(True)

axs[3].bar(range(len(quick_as_8000)), quick_as_8000['Runtime'], color="blue")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.05)
axs[3].grid(True)

axs[4].bar(range(len(quick_as_16000)), quick_as_16000['Runtime'], color="blue")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.05)
axs[4].grid(True)


fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("QuickSort on Almost-sorted Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("quickas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
quick_tr_runtime = []
quick_as_runtime = []

working_mean = 0

quick_tr_runtime.append(quick_tr_1000['Runtime'].mean())
quick_tr_runtime.append(quick_tr_2000['Runtime'].mean())
quick_tr_runtime.append(quick_tr_4000['Runtime'].mean())
quick_tr_runtime.append(quick_tr_8000['Runtime'].mean())
quick_tr_runtime.append(quick_tr_16000['Runtime'].mean())

quick_as_runtime.append(quick_as_1000['Runtime'].mean())
quick_as_runtime.append(quick_as_2000['Runtime'].mean())
quick_as_runtime.append(quick_as_4000['Runtime'].mean())
quick_as_runtime.append(quick_as_8000['Runtime'].mean())
quick_as_runtime.append(quick_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, quick_tr_runtime, label='Quick TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, quick_as_runtime, label='Quick AS runtime', marker='o')

# Adding titles and labels
plt.title('QuickSort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("quickrun.png")
# Display the plot
plt.show()

# %% [markdown]
# ### InsertionSort Time Analysis

# %%
insertion_tr_1000 = tr_df[(tr_df['Algorithm'] == 'InsertionSort') & (tr_df['Data Size'] == 1000)]
insertion_tr_2000 = tr_df[(tr_df['Algorithm'] == 'InsertionSort') & (tr_df['Data Size'] == 2000)]
insertion_tr_4000 = tr_df[(tr_df['Algorithm'] == 'InsertionSort') & (tr_df['Data Size'] == 4000)]
insertion_tr_8000 = tr_df[(tr_df['Algorithm'] == 'InsertionSort') & (tr_df['Data Size'] == 8000)]
insertion_tr_16000 = tr_df[(tr_df['Algorithm'] == 'InsertionSort') & (tr_df['Data Size'] == 16000)]

insertion_as_1000 = as_df[(as_df['Algorithm'] == 'InsertionSort') & (as_df['Data Size'] == 1000)]
insertion_as_2000 = as_df[(as_df['Algorithm'] == 'InsertionSort') & (as_df['Data Size'] == 2000)]
insertion_as_4000 = as_df[(as_df['Algorithm'] == 'InsertionSort') & (as_df['Data Size'] == 4000)]
insertion_as_8000 = as_df[(as_df['Algorithm'] == 'InsertionSort') & (as_df['Data Size'] == 8000)]
insertion_as_16000 = as_df[(as_df['Algorithm'] == 'InsertionSort') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### InsertionSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("InsertionSort Statistics on True Random Data")
insertion_sort_tr = tr_df[tr_df['Algorithm'] == 'InsertionSort']
insertion_tr_stats = insertion_sort_tr.groupby('Data Size').describe()
insertion_tr_stats.drop(columns='Theoretical Big-O', inplace=True)
insertion_tr_stats.reset_index(inplace=True)
insertion_tr_stats.columns = insertion_tr_stats.columns.map(' '.join)
insertion_tr_stats = pd.DataFrame(insertion_tr_stats)
print(insertion_tr_stats, '\n')

print("InsertionSort Statistics on Almost Sorted Data")
insertion_sort_as = as_df[as_df['Algorithm'] == 'InsertionSort']
insertion_as_stats = insertion_sort_as.groupby('Data Size').describe()
insertion_as_stats.drop(columns='Theoretical Big-O', inplace=True)
insertion_as_stats.reset_index(inplace=True)
insertion_as_stats.columns = insertion_as_stats.columns.map(' '.join)
insertion_as_stats = pd.DataFrame(insertion_as_stats)
print(insertion_as_stats)
# Out:
# InsertionSort Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.014235     0.000111     0.014077     0.014173     0.014259     0.014324     0.014345
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.059809     0.000957     0.058982     0.059348     0.059504     0.059766     0.061443
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.237579     0.001902     0.235432     0.236300     0.237597     0.238182     0.240383
# ...

# %% [markdown]
# #### Plotting InsertionSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(insertion_tr_1000)), insertion_tr_1000['Runtime'], color="red")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 5.3)
axs[0].grid(True)

axs[1].bar(range(len(insertion_tr_2000)), insertion_tr_2000['Runtime'], color="red")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 5.3)
axs[1].grid(True)

axs[2].bar(range(len(insertion_tr_4000)), insertion_tr_4000['Runtime'], color="red")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 5.3)
axs[2].grid(True)

axs[3].bar(range(len(insertion_tr_8000)), insertion_tr_8000['Runtime'], color="red")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 5.3)
axs[3].grid(True)

axs[4].bar(range(len(insertion_tr_16000)), insertion_tr_16000['Runtime'], color="red")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 5.3)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("InsertionSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("insertiontr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(insertion_as_1000)), insertion_as_1000['Runtime'], color="red")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 5.3)
axs[0].grid(True)

axs[1].bar(range(len(insertion_as_2000)), insertion_as_2000['Runtime'], color="red")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 5.3)
axs[1].grid(True)

axs[2].bar(range(len(insertion_as_4000)), insertion_as_4000['Runtime'], color="red")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 5.3)
axs[2].grid(True)

axs[3].bar(range(len(insertion_as_8000)), insertion_as_8000['Runtime'], color="red")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 5.3)
axs[3].grid(True)

axs[4].bar(range(len(insertion_as_16000)), insertion_as_16000['Runtime'], color="red")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 5.3)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("InsertionSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("insertionas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
insertion_tr_runtime = []
insertion_as_runtime = []

working_mean = 0

insertion_tr_runtime.append(insertion_tr_1000['Runtime'].mean())
insertion_tr_runtime.append(insertion_tr_2000['Runtime'].mean())
insertion_tr_runtime.append(insertion_tr_4000['Runtime'].mean())
insertion_tr_runtime.append(insertion_tr_8000['Runtime'].mean())
insertion_tr_runtime.append(insertion_tr_16000['Runtime'].mean())

insertion_as_runtime.append(insertion_as_1000['Runtime'].mean())
insertion_as_runtime.append(insertion_as_2000['Runtime'].mean())
insertion_as_runtime.append(insertion_as_4000['Runtime'].mean())
insertion_as_runtime.append(insertion_as_8000['Runtime'].mean())
insertion_as_runtime.append(insertion_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, insertion_tr_runtime, label='Insertion TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, insertion_as_runtime, label='Insertion AS runtime', marker='o')

# Adding titles and labels
plt.title('InsertionSort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("insertionrun.png")
# Display the plot
plt.show()

# %% [markdown]
# ### ShellSort Time Analysis

# %%
# ShellSort1 TR
shell1_tr_1000 = tr_df[(tr_df['Algorithm'] == 'ShellSort1') & (tr_df['Data Size'] == 1000)]
shell1_tr_2000 = tr_df[(tr_df['Algorithm'] == 'ShellSort1') & (tr_df['Data Size'] == 2000)]
shell1_tr_4000 = tr_df[(tr_df['Algorithm'] == 'ShellSort1') & (tr_df['Data Size'] == 4000)]
shell1_tr_8000 = tr_df[(tr_df['Algorithm'] == 'ShellSort1') & (tr_df['Data Size'] == 8000)]
shell1_tr_16000 = tr_df[(tr_df['Algorithm'] == 'ShellSort1') & (tr_df['Data Size'] == 16000)]
#ShellSort2 TR
shell2_tr_1000 = tr_df[(tr_df['Algorithm'] == 'ShellSort2') & (tr_df['Data Size'] == 1000)]
shell2_tr_2000 = tr_df[(tr_df['Algorithm'] == 'ShellSort2') & (tr_df['Data Size'] == 2000)]
shell2_tr_4000 = tr_df[(tr_df['Algorithm'] == 'ShellSort2') & (tr_df['Data Size'] == 4000)]
shell2_tr_8000 = tr_df[(tr_df['Algorithm'] == 'ShellSort2') & (tr_df['Data Size'] == 8000)]
shell2_tr_16000 = tr_df[(tr_df['Algorithm'] == 'ShellSort2') & (tr_df['Data Size'] == 16000)]

#ShellSort1 AS
shell1_as_1000 = as_df[(as_df['Algorithm'] == 'ShellSort1') & (as_df['Data Size'] == 1000)]
shell1_as_2000 = as_df[(as_df['Algorithm'] == 'ShellSort1') & (as_df['Data Size'] == 2000)]
shell1_as_4000 = as_df[(as_df['Algorithm'] == 'ShellSort1') & (as_df['Data Size'] == 4000)]
shell1_as_8000 = as_df[(as_df['Algorithm'] == 'ShellSort1') & (as_df['Data Size'] == 8000)]
shell1_as_16000 = as_df[(as_df['Algorithm'] == 'ShellSort1') & (as_df['Data Size'] == 16000)]
#ShellSort2 AS
shell2_as_1000 = as_df[(as_df['Algorithm'] == 'ShellSort2') & (as_df['Data Size'] == 1000)]
shell2_as_2000 = as_df[(as_df['Algorithm'] == 'ShellSort2') & (as_df['Data Size'] == 2000)]
shell2_as_4000 = as_df[(as_df['Algorithm'] == 'ShellSort2') & (as_df['Data Size'] == 4000)]
shell2_as_8000 = as_df[(as_df['Algorithm'] == 'ShellSort2') & (as_df['Data Size'] == 8000)]
shell2_as_16000 = as_df[(as_df['Algorithm'] == 'ShellSort2') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### ShellSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("ShellSort1 Statistics on True Random Data")
shell_sort_tr1 = tr_df[tr_df['Algorithm'] == 'ShellSort1']
shell_tr_stats1 = shell_sort_tr1.groupby('Data Size').describe()
shell_tr_stats1.drop(columns='Theoretical Big-O', inplace=True)
shell_tr_stats1.reset_index(inplace=True)
shell_tr_stats1.columns = shell_tr_stats1.columns.map(' '.join)
shell_tr_stats1 = pd.DataFrame(shell_tr_stats1)
print(shell_tr_stats1, '\n')

print("ShellSort2 Statistics on True Random Data")
shell_sort_tr2 = tr_df[tr_df['Algorithm'] == 'ShellSort2']
shell_tr_stats2 = shell_sort_tr2.groupby('Data Size').describe()
shell_tr_stats2.drop(columns='Theoretical Big-O', inplace=True)
shell_tr_stats2.reset_index(inplace=True)
shell_tr_stats2.columns = shell_tr_stats2.columns.map(' '.join)
shell_tr_stats2 = pd.DataFrame(shell_tr_stats2)
print(shell_tr_stats2, '\n')

print("ShellSort1 Statistics on Almost Sorted Data")
shell_sort_as1 = as_df[as_df['Algorithm'] == 'ShellSort1']
shell_as_stats1 = shell_sort_as1.groupby('Data Size').describe()
shell_as_stats1.drop(columns='Theoretical Big-O', inplace=True)
shell_as_stats1.reset_index(inplace=True)
shell_as_stats1.columns = shell_as_stats1.columns.map(' '.join)
shell_as_stats1 = pd.DataFrame(shell_as_stats1)
print(shell_as_stats1,'\n')

print("ShellSort2 Statistics on Almost Sorted Data")
shell_sort_as2 = as_df[as_df['Algorithm'] == 'ShellSort2']
shell_as_stats2 = shell_sort_as2.groupby('Data Size').describe()
shell_as_stats2.drop(columns='Theoretical Big-O', inplace=True)
shell_as_stats2.reset_index(inplace=True)
shell_as_stats2.columns = shell_as_stats2.columns.map(' '.join)
shell_as_stats2 = pd.DataFrame(shell_as_stats2)
print(shell_as_stats2)
# Out:
# ShellSort1 Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.004920     0.000105     0.004828     0.004828     0.004879     0.005019     0.005045
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.018754     0.000235     0.018534     0.018603     0.018668     0.018843     0.019120
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.072155     0.002094     0.070258     0.070367     0.071397     0.073984     0.074768
# ...

# %% [markdown]
# #### Plotting ShellSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(2, 5, figsize=(30, 10))

axs[0,0].bar(range(len(shell1_tr_1000)), shell1_tr_1000['Runtime'], color="skyblue")
axs[0,0].set_title('ShellSort1 Data Size 1000')
axs[0,0].set_ylim(0, 1.6)
axs[0,0].grid(True)

axs[0,1].bar(range(len(shell1_tr_2000)), shell1_tr_2000['Runtime'], color="skyblue")
axs[0,1].set_title('ShellSort1 Data Size 2000')
axs[0,1].set_ylim(0, 1.6)
axs[0,1].grid(True)

axs[0,2].bar(range(len(shell1_tr_4000)), shell1_tr_4000['Runtime'], color="skyblue")
axs[0,2].set_title('ShellSort1 Data Size 4000')
axs[0,2].set_ylim(0, 1.6)
axs[0,2].grid(True)

axs[0,3].bar(range(len(shell1_tr_8000)), shell1_tr_8000['Runtime'], color="skyblue")
axs[0,3].set_title('ShellSort1 Data Size 8000')
axs[0,3].set_ylim(0, 1.6)
axs[0,3].grid(True)

axs[0,4].bar(range(len(shell1_tr_16000)), shell1_tr_16000['Runtime'], color="skyblue")
axs[0,4].set_title('ShellSort1 Data Size 16000')
axs[0,4].set_ylim(0, 1.6)
axs[0,4].grid(True)

axs[1,0].bar(range(len(shell2_tr_1000)), shell2_tr_1000['Runtime'], color="skyblue")
axs[1,0].set_title('ShellSort2 Data Size 1000')
axs[1,0].set_ylim(0, 1.6)
axs[1,0].grid(True)

axs[1,1].bar(range(len(shell2_tr_2000)), shell2_tr_2000['Runtime'], color="skyblue")
axs[1,1].set_title('ShellSort2 Data Size 2000')
axs[1,1].set_ylim(0, 1.6)
axs[1,1].grid(True)

axs[1,2].bar(range(len(shell2_tr_4000)), shell2_tr_4000['Runtime'], color="skyblue")
axs[1,2].set_title('ShellSort2 Data Size 4000')
axs[1,2].set_ylim(0, 1.6)
axs[1,2].grid(True)

axs[1,3].bar(range(len(shell2_tr_8000)), shell2_tr_8000['Runtime'], color="skyblue")
axs[1,3].set_title('ShellSort2 Data Size 8000')
axs[1,3].set_ylim(0, 1.6)
axs[1,3].grid(True)

axs[1,4].bar(range(len(shell2_tr_16000)), shell2_tr_16000['Runtime'], color="skyblue")
axs[1,4].set_title('ShellSort2 Data Size 16000')
axs[1,4].set_ylim(0, 1.6)
axs[1,4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("ShellSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("shelltr.png")
plt.show()

fig, axs = plt.subplots(2, 5, figsize=(30, 10))

axs[0,0].bar(range(len(shell1_as_1000)), shell1_as_1000['Runtime'], color="skyblue")
axs[0,0].set_title('ShellSort1 Data Size 1000')
axs[0,0].set_ylim(0, 1.6)
axs[0,0].grid(True)

axs[0,1].bar(range(len(shell1_as_2000)), shell1_as_2000['Runtime'], color="skyblue")
axs[0,1].set_title('ShellSort1 Data Size 2000')
axs[0,1].set_ylim(0, 1.6)
axs[0,1].grid(True)

axs[0,2].bar(range(len(shell1_as_4000)), shell1_as_4000['Runtime'], color="skyblue")
axs[0,2].set_title('ShellSort1 Data Size 4000')
axs[0,2].set_ylim(0, 1.6)
axs[0,2].grid(True)

axs[0,3].bar(range(len(shell1_as_8000)), shell1_as_8000['Runtime'], color="skyblue")
axs[0,3].set_title('ShellSort1 Data Size 8000')
axs[0,3].set_ylim(0, 1.6)
axs[0,3].grid(True)

axs[0,4].bar(range(len(shell1_as_16000)), shell1_as_16000['Runtime'], color="skyblue")
axs[0,4].set_title('ShellSort1 Data Size 16000')
axs[0,4].set_ylim(0, 1.6)
axs[0,4].grid(True)

axs[1,0].bar(range(len(shell2_as_1000)), shell2_as_1000['Runtime'], color="skyblue")
axs[1,0].set_title('ShellSort2 Data Size 1000')
axs[1,0].set_ylim(0, 1.6)
axs[1,0].grid(True)

axs[1,1].bar(range(len(shell2_as_2000)), shell2_as_2000['Runtime'], color="skyblue")
axs[1,1].set_title('ShellSort2 Data Size 2000')
axs[1,1].set_ylim(0, 1.6)
axs[1,1].grid(True)

axs[1,2].bar(range(len(shell2_as_4000)), shell2_as_4000['Runtime'], color="skyblue")
axs[1,2].set_title('ShellSort2 Data Size 4000')
axs[1,2].set_ylim(0, 1.6)
axs[1,2].grid(True)

axs[1,3].bar(range(len(shell2_as_8000)), shell2_as_8000['Runtime'], color="skyblue")
axs[1,3].set_title('ShellSort2 Data Size 8000')
axs[1,3].set_ylim(0, 1.6)
axs[1,3].grid(True)

axs[1,4].bar(range(len(shell2_as_16000)), shell2_as_16000['Runtime'], color="skyblue")
axs[1,4].set_title('ShellSort2 Data Size 16000')
axs[1,4].set_ylim(0, 1.6)
axs[1,4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("ShellSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("shellas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
shell1_tr_runtime = []
shell1_as_runtime = []

working_mean = 0

shell1_tr_runtime.append(shell1_tr_1000['Runtime'].mean())
shell1_tr_runtime.append(shell1_tr_2000['Runtime'].mean())
shell1_tr_runtime.append(shell1_tr_4000['Runtime'].mean())
shell1_tr_runtime.append(shell1_tr_8000['Runtime'].mean())
shell1_tr_runtime.append(shell1_tr_16000['Runtime'].mean())

shell1_as_runtime.append(shell1_as_1000['Runtime'].mean())
shell1_as_runtime.append(shell1_as_2000['Runtime'].mean())
shell1_as_runtime.append(shell1_as_4000['Runtime'].mean())
shell1_as_runtime.append(shell1_as_8000['Runtime'].mean())
shell1_as_runtime.append(shell1_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, shell1_tr_runtime, label='ShellSort(7,3,1) TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, shell1_as_runtime, label='ShellSort(7,3,1) AS runtime', marker='o')

# Adding titles and labels
plt.title('ShellSort (7, 3, 1 gaps) Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("shell1run.png")
# Display the plot
plt.show()

#Size vs. Execution Time in One Plot
shell2_tr_runtime = []
shell2_as_runtime = []

working_mean = 0

shell2_tr_runtime.append(shell2_tr_1000['Runtime'].mean())
shell2_tr_runtime.append(shell2_tr_2000['Runtime'].mean())
shell2_tr_runtime.append(shell2_tr_4000['Runtime'].mean())
shell2_tr_runtime.append(shell2_tr_8000['Runtime'].mean())
shell2_tr_runtime.append(shell2_tr_16000['Runtime'].mean())

shell2_as_runtime.append(shell2_as_1000['Runtime'].mean())
shell2_as_runtime.append(shell2_as_2000['Runtime'].mean())
shell2_as_runtime.append(shell2_as_4000['Runtime'].mean())
shell2_as_runtime.append(shell2_as_8000['Runtime'].mean())
shell2_as_runtime.append(shell2_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, shell2_tr_runtime, label='ShellSort(1000,100,10,1) TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, shell2_as_runtime, label='ShellSort(1000,100,10,1) AS runtime', marker='o')

# Adding titles and labels
plt.title('ShellSort (1000, 100, 10, 1 gaps) Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("shell2run.png")
# Display the plot
plt.show()

# %% [markdown]
# ### BucketSort Time Analysis

# %%
bucket_tr_1000 = tr_df[(tr_df['Algorithm'] == 'BucketSort') & (tr_df['Data Size'] == 1000)]
bucket_tr_2000 = tr_df[(tr_df['Algorithm'] == 'BucketSort') & (tr_df['Data Size'] == 2000)]
bucket_tr_4000 = tr_df[(tr_df['Algorithm'] == 'BucketSort') & (tr_df['Data Size'] == 4000)]
bucket_tr_8000 = tr_df[(tr_df['Algorithm'] == 'BucketSort') & (tr_df['Data Size'] == 8000)]
bucket_tr_16000 = tr_df[(tr_df['Algorithm'] == 'BucketSort') & (tr_df['Data Size'] == 16000)]

bucket_as_1000 = as_df[(as_df['Algorithm'] == 'BucketSort') & (as_df['Data Size'] == 1000)]
bucket_as_2000 = as_df[(as_df['Algorithm'] == 'BucketSort') & (as_df['Data Size'] == 2000)]
bucket_as_4000 = as_df[(as_df['Algorithm'] == 'BucketSort') & (as_df['Data Size'] == 4000)]
bucket_as_8000 = as_df[(as_df['Algorithm'] == 'BucketSort') & (as_df['Data Size'] == 8000)]
bucket_as_16000 = as_df[(as_df['Algorithm'] == 'BucketSort') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### BucketSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("BucketSort Statistics on True Random Data")
bucket_sort_tr = tr_df[tr_df['Algorithm'] == 'BucketSort']
bucket_tr_stats = bucket_sort_tr.groupby('Data Size').describe()
bucket_tr_stats.drop(columns='Theoretical Big-O', inplace=True)
bucket_tr_stats.reset_index(inplace=True)
bucket_tr_stats.columns = bucket_tr_stats.columns.map(' '.join)
bucket_tr_stats = pd.DataFrame(bucket_tr_stats)
print(bucket_tr_stats, '\n')

print("BucketSort Statistics on Almost Sorted Data")
bucket_sort_as = as_df[as_df['Algorithm'] == 'BucketSort']
bucket_as_stats = bucket_sort_as.groupby('Data Size').describe()
bucket_as_stats.drop(columns='Theoretical Big-O', inplace=True)
bucket_as_stats.reset_index(inplace=True)
bucket_as_stats.columns = bucket_as_stats.columns.map(' '.join)
bucket_as_stats = pd.DataFrame(bucket_as_stats)
print(bucket_as_stats)
# Out:
# BucketSort Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.000166     0.000032     0.000145     0.000148     0.000151     0.000166     0.000221
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.000308     0.000019     0.000296     0.000296     0.000302     0.000304     0.000341
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.001994     0.003129     0.000507     0.000515     0.000525     0.000836     0.007586
# ...

# %% [markdown]
# #### Plotting BucketSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(bucket_tr_1000)), bucket_tr_1000['Runtime'], color="pink")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.005)
axs[0].grid(True)

axs[1].bar(range(len(bucket_tr_2000)), bucket_tr_2000['Runtime'], color="pink")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.005)
axs[1].grid(True)

axs[2].bar(range(len(bucket_tr_4000)), bucket_tr_4000['Runtime'], color="pink")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.005)
axs[2].grid(True)

axs[3].bar(range(len(bucket_tr_8000)), bucket_tr_8000['Runtime'], color="pink")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.005)
axs[3].grid(True)

axs[4].bar(range(len(bucket_tr_16000)), bucket_tr_16000['Runtime'], color="pink")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.005)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("BucketSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("buckettr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(bucket_as_1000)), bucket_as_1000['Runtime'], color="pink")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.005)
axs[0].grid(True)

axs[1].bar(range(len(bucket_as_2000)), bucket_as_2000['Runtime'], color="pink")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.005)
axs[1].grid(True)

axs[2].bar(range(len(bucket_as_4000)), bucket_as_4000['Runtime'], color="pink")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.005)
axs[2].grid(True)

axs[3].bar(range(len(bucket_as_8000)), bucket_as_8000['Runtime'], color="pink")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.005)
axs[3].grid(True)

axs[4].bar(range(len(bucket_as_16000)), bucket_as_16000['Runtime'], color="pink")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.005)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("BucketSort on Almost-sorted Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("bucketas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
bucket_tr_runtime = []
bucket_as_runtime = []

working_mean = 0

bucket_tr_runtime.append(bucket_tr_1000['Runtime'].mean())
bucket_tr_runtime.append(bucket_tr_2000['Runtime'].mean())
bucket_tr_runtime.append(bucket_tr_4000['Runtime'].mean())
bucket_tr_runtime.append(bucket_tr_8000['Runtime'].mean())
bucket_tr_runtime.append(bucket_tr_16000['Runtime'].mean())

bucket_as_runtime.append(bucket_as_1000['Runtime'].mean())
bucket_as_runtime.append(bucket_as_2000['Runtime'].mean())
bucket_as_runtime.append(bucket_as_4000['Runtime'].mean())
bucket_as_runtime.append(bucket_as_8000['Runtime'].mean())
bucket_as_runtime.append(bucket_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, bucket_tr_runtime, label='BucketSort TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, bucket_as_runtime, label='BucketSort AS runtime', marker='o')

# Adding titles and labels
plt.title('BucketSort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("bucketrun.png")
# Display the plot
plt.show()

# %% [markdown]
# ### RadixSort Time Analysis

# %%
radix_tr_1000 = tr_df[(tr_df['Algorithm'] == 'RadixSort') & (tr_df['Data Size'] == 1000)]
radix_tr_2000 = tr_df[(tr_df['Algorithm'] == 'RadixSort') & (tr_df['Data Size'] == 2000)]
radix_tr_4000 = tr_df[(tr_df['Algorithm'] == 'RadixSort') & (tr_df['Data Size'] == 4000)]
radix_tr_8000 = tr_df[(tr_df['Algorithm'] == 'RadixSort') & (tr_df['Data Size'] == 8000)]
radix_tr_16000 = tr_df[(tr_df['Algorithm'] == 'RadixSort') & (tr_df['Data Size'] == 16000)]

radix_as_1000 = as_df[(as_df['Algorithm'] == 'RadixSort') & (as_df['Data Size'] == 1000)]
radix_as_2000 = as_df[(as_df['Algorithm'] == 'RadixSort') & (as_df['Data Size'] == 2000)]
radix_as_4000 = as_df[(as_df['Algorithm'] == 'RadixSort') & (as_df['Data Size'] == 4000)]
radix_as_8000 = as_df[(as_df['Algorithm'] == 'RadixSort') & (as_df['Data Size'] == 8000)]
radix_as_16000 = as_df[(as_df['Algorithm'] == 'RadixSort') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### RadixSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("RadixSort Statistics on True Random Data")
radix_sort_tr = tr_df[tr_df['Algorithm'] == 'RadixSort']
radix_tr_stats = radix_sort_tr.groupby('Data Size').describe()
radix_tr_stats.drop(columns='Theoretical Big-O', inplace=True)
radix_tr_stats.reset_index(inplace=True)
radix_tr_stats.columns = radix_tr_stats.columns.map(' '.join)
radix_tr_stats = pd.DataFrame(radix_tr_stats)
print(radix_tr_stats, '\n')

print("RadixSort Statistics on Almost Sorted Data")
radix_sort_as = as_df[as_df['Algorithm'] == 'RadixSort']
radix_as_stats = radix_sort_as.groupby('Data Size').describe()
radix_as_stats.drop(columns='Theoretical Big-O', inplace=True)
radix_as_stats.reset_index(inplace=True)
radix_as_stats.columns = radix_as_stats.columns.map(' '.join)
radix_as_stats = pd.DataFrame(radix_as_stats)
print(radix_as_stats)
# Out:
# RadixSort Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.000544     0.000065     0.000429     0.000559     0.000574     0.000578     0.000578
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.001131     0.000043     0.001098     0.001102     0.001111     0.001139     0.001203
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.002226     0.000042     0.002184     0.002195     0.002211     0.002260     0.002281
# ...

# %% [markdown]
# #### Plotting RadixSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(radix_tr_1000)), radix_tr_1000['Runtime'], color="purple")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.02)
axs[0].grid(True)

axs[1].bar(range(len(radix_tr_2000)), radix_tr_2000['Runtime'], color="purple")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.02)
axs[1].grid(True)

axs[2].bar(range(len(radix_tr_4000)), radix_tr_4000['Runtime'], color="purple")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.02)
axs[2].grid(True)

axs[3].bar(range(len(radix_tr_8000)), radix_tr_8000['Runtime'], color="purple")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.02)
axs[3].grid(True)

axs[4].bar(range(len(radix_tr_16000)), radix_tr_16000['Runtime'], color="purple")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.02)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("RadixSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("radixtr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(radix_as_1000)), radix_as_1000['Runtime'], color="purple")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.02)
axs[0].grid(True)

axs[1].bar(range(len(radix_as_2000)), radix_as_2000['Runtime'], color="purple")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.02)
axs[1].grid(True)

axs[2].bar(range(len(radix_as_4000)), radix_as_4000['Runtime'], color="purple")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.02)
axs[2].grid(True)

axs[3].bar(range(len(radix_as_8000)), radix_as_8000['Runtime'], color="purple")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.02)
axs[3].grid(True)

axs[4].bar(range(len(radix_as_16000)), radix_as_16000['Runtime'], color="purple")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.02)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("RadixSort on Almost-sorted Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("radixas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
radix_tr_runtime = []
radix_as_runtime = []

working_mean = 0

radix_tr_runtime.append(radix_tr_1000['Runtime'].mean())
radix_tr_runtime.append(radix_tr_2000['Runtime'].mean())
radix_tr_runtime.append(radix_tr_4000['Runtime'].mean())
radix_tr_runtime.append(radix_tr_8000['Runtime'].mean())
radix_tr_runtime.append(radix_tr_16000['Runtime'].mean())

radix_as_runtime.append(radix_as_1000['Runtime'].mean())
radix_as_runtime.append(radix_as_2000['Runtime'].mean())
radix_as_runtime.append(radix_as_4000['Runtime'].mean())
radix_as_runtime.append(radix_as_8000['Runtime'].mean())
radix_as_runtime.append(radix_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, radix_tr_runtime, label='RadixSort TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, radix_as_runtime, label='RadixSort AS runtime', marker='o')

# Adding titles and labels
plt.title('RadixSort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("radixrun.png")
# Display the plot
plt.show()

# %% [markdown]
# ### BinaryInsertionSort Time Analysis

# %%
bis_tr_1000 = tr_df[(tr_df['Algorithm'] == 'CustomSort1') & (tr_df['Data Size'] == 1000)]
bis_tr_2000 = tr_df[(tr_df['Algorithm'] == 'CustomSort1') & (tr_df['Data Size'] == 2000)]
bis_tr_4000 = tr_df[(tr_df['Algorithm'] == 'CustomSort1') & (tr_df['Data Size'] == 4000)]
bis_tr_8000 = tr_df[(tr_df['Algorithm'] == 'CustomSort1') & (tr_df['Data Size'] == 8000)]
bis_tr_16000 = tr_df[(tr_df['Algorithm'] == 'CustomSort1') & (tr_df['Data Size'] == 16000)]

bis_as_1000 = as_df[(as_df['Algorithm'] == 'CustomSort1') & (as_df['Data Size'] == 1000)]
bis_as_2000 = as_df[(as_df['Algorithm'] == 'CustomSort1') & (as_df['Data Size'] == 2000)]
bis_as_4000 = as_df[(as_df['Algorithm'] == 'CustomSort1') & (as_df['Data Size'] == 4000)]
bis_as_8000 = as_df[(as_df['Algorithm'] == 'CustomSort1') & (as_df['Data Size'] == 8000)]
bis_as_16000 = as_df[(as_df['Algorithm'] == 'CustomSort1') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### BinaryInsertionSort: Descriptive Statistics

# %%
pd.set_option('display.width', 500)
print("BinaryInsertionSort Statistics on True Random Data")
bis_sort_tr = tr_df[tr_df['Algorithm'] == 'CustomSort1']
bis_tr_stats = bis_sort_tr.groupby('Data Size').describe()
bis_tr_stats.drop(columns='Theoretical Big-O', inplace=True)
bis_tr_stats.reset_index(inplace=True)
bis_tr_stats.columns = bis_tr_stats.columns.map(' '.join)
bis_tr_stats = pd.DataFrame(bis_tr_stats)
print(bis_tr_stats, '\n')

print("BinaryInsertionSort Statistics on Almost Sorted Data")
bis_sort_as = as_df[as_df['Algorithm'] == 'CustomSort2']
bis_as_stats = bis_sort_as.groupby('Data Size').describe()
bis_as_stats.drop(columns='Theoretical Big-O', inplace=True)
bis_as_stats.reset_index(inplace=True)
bis_as_stats.columns = bis_as_stats.columns.map(' '.join)
bis_as_stats = pd.DataFrame(bis_as_stats)
print(bis_as_stats)
# Out:
# BinaryInsertionSort Statistics on True Random Data
#    Data Size   Seed count  Seed mean    Seed std  Seed min  Seed 25%  Seed 50%  Seed 75%  Seed max  Runtime count  Runtime mean  Runtime std  Runtime min  Runtime 25%  Runtime 50%  Runtime 75%  Runtime max
# 0        1000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.001888     0.000033     0.001862     0.001863     0.001881     0.001889     0.001943
# 1        2000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.005836     0.000073     0.005752     0.005762     0.005875     0.005878     0.005911
# 2        4000         5.0      688.4  307.378106     260.0     464.0     883.0     893.0     942.0            5.0      0.021105     0.000108     0.020917     0.021127     0.021127     0.021169     0.021186
# ...

# %% [markdown]
# #### Plotting BinaryInsertionSort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(bis_tr_1000)), bis_tr_1000['Runtime'], color="green")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.3)
axs[0].grid(True)

axs[1].bar(range(len(bis_tr_2000)), bis_tr_2000['Runtime'], color="green")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.3)
axs[1].grid(True)

axs[2].bar(range(len(bis_tr_4000)), bis_tr_4000['Runtime'], color="green")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.3)
axs[2].grid(True)

axs[3].bar(range(len(bis_tr_8000)), bis_tr_8000['Runtime'], color="green")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.3)
axs[3].grid(True)

axs[4].bar(range(len(bis_tr_16000)), bis_tr_16000['Runtime'], color="green")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.4)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("BinaryInsertionSort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("bistr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(bis_as_1000)), bis_as_1000['Runtime'], color="green")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.3)
axs[0].grid(True)

axs[1].bar(range(len(bis_as_2000)), bis_as_2000['Runtime'], color="green")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.3)
axs[1].grid(True)

axs[2].bar(range(len(bis_as_4000)), bis_as_4000['Runtime'], color="green")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.3)
axs[2].grid(True)

axs[3].bar(range(len(bis_as_8000)), bis_as_8000['Runtime'], color="green")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.3)
axs[3].grid(True)

axs[4].bar(range(len(bis_as_16000)), bis_as_16000['Runtime'], color="green")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.4)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("BinaryInsertionSort on Almost-sorted Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("bisas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
bis_tr_runtime = []
bis_as_runtime = []

working_mean = 0

bis_tr_runtime.append(bis_tr_1000['Runtime'].mean())
bis_tr_runtime.append(bis_tr_2000['Runtime'].mean())
bis_tr_runtime.append(bis_tr_4000['Runtime'].mean())
bis_tr_runtime.append(bis_tr_8000['Runtime'].mean())
bis_tr_runtime.append(bis_tr_16000['Runtime'].mean())

bis_as_runtime.append(bis_as_1000['Runtime'].mean())
bis_as_runtime.append(bis_as_2000['Runtime'].mean())
bis_as_runtime.append(bis_as_4000['Runtime'].mean())
bis_as_runtime.append(bis_as_8000['Runtime'].mean())
bis_as_runtime.append(bis_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, bis_tr_runtime, label='Binary InsertionSort TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, bis_as_runtime, label='Binary InsertionSort AS runtime', marker='o')

# Adding titles and labels
plt.title('Binary InsertionSort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("bisrun.png")
# Display the plot
plt.show()

# %% [markdown]
# ### QuickSort with median-of-medians Time Analysis

# %%
mom_tr_1000 = tr_df[(tr_df['Algorithm'] == 'CustomSort2') & (tr_df['Data Size'] == 1000)]
mom_tr_2000 = tr_df[(tr_df['Algorithm'] == 'CustomSort2') & (tr_df['Data Size'] == 2000)]
mom_tr_4000 = tr_df[(tr_df['Algorithm'] == 'CustomSort2') & (tr_df['Data Size'] == 4000)]
mom_tr_8000 = tr_df[(tr_df['Algorithm'] == 'CustomSort2') & (tr_df['Data Size'] == 8000)]
mom_tr_16000 = tr_df[(tr_df['Algorithm'] == 'CustomSort2') & (tr_df['Data Size'] == 16000)]

mom_as_1000 = as_df[(as_df['Algorithm'] == 'CustomSort2') & (as_df['Data Size'] == 1000)]
mom_as_2000 = as_df[(as_df['Algorithm'] == 'CustomSort2') & (as_df['Data Size'] == 2000)]
mom_as_4000 = as_df[(as_df['Algorithm'] == 'CustomSort2') & (as_df['Data Size'] == 4000)]
mom_as_8000 = as_df[(as_df['Algorithm'] == 'CustomSort2') & (as_df['Data Size'] == 8000)]
mom_as_16000 = as_df[(as_df['Algorithm'] == 'CustomSort2') & (as_df['Data Size'] == 16000)]

# %% [markdown]
# #### MoM Quicksort: Descriptive Statistics

# %% [markdown]
# #### Plotting MoM Quicksort: True Random vs. Almost Sorted

# %%
fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(mom_tr_1000)), mom_tr_1000['Runtime'], color="green")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.3)
axs[0].grid(True)

axs[1].bar(range(len(mom_tr_2000)), mom_tr_2000['Runtime'], color="green")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.3)
axs[1].grid(True)

axs[2].bar(range(len(mom_tr_4000)), mom_tr_4000['Runtime'], color="green")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.3)
axs[2].grid(True)

axs[3].bar(range(len(mom_tr_8000)), mom_tr_8000['Runtime'], color="green")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.3)
axs[3].grid(True)

axs[4].bar(range(len(mom_tr_16000)), mom_tr_16000['Runtime'], color="green")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.4)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("Simplified Timsort on True Random Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("./figure/momtr.png")
plt.show()

fig, axs = plt.subplots(1, 5, figsize=(30, 10))

axs[0].bar(range(len(mom_as_1000)), mom_as_1000['Runtime'], color="green")
axs[0].set_title('Data Size 1000')
axs[0].set_ylim(0, 0.3)
axs[0].grid(True)

axs[1].bar(range(len(mom_as_2000)), mom_as_2000['Runtime'], color="green")
axs[1].set_title('Data Size 2000')
axs[1].set_ylim(0, 0.3)
axs[1].grid(True)

axs[2].bar(range(len(mom_as_4000)), mom_as_4000['Runtime'], color="green")
axs[2].set_title('Data Size 4000')
axs[2].set_ylim(0, 0.3)
axs[2].grid(True)

axs[3].bar(range(len(mom_as_8000)), mom_as_8000['Runtime'], color="green")
axs[3].set_title('Data Size 8000')
axs[3].set_ylim(0, 0.3)
axs[3].grid(True)

axs[4].bar(range(len(mom_as_16000)), mom_as_16000['Runtime'], color="green")
axs[4].set_title('Data Size 16000')
axs[4].set_ylim(0, 0.4)
axs[4].grid(True)

fig.supxlabel("Trial #", fontsize=20)
fig.supylabel("Runtime(seconds)", fontsize=20)
fig.suptitle("Simplified Timsort on Almost-sorted Data", fontsize=25)
fig.subplots_adjust(left=0.05, right=0.95) 
plt.savefig("./figure/momas.png")
plt.show()

# %%
#Size vs. Execution Time in One Plot
mom_tr_runtime = []
mom_as_runtime = []

working_mean = 0

mom_tr_runtime.append(mom_tr_1000['Runtime'].mean())
mom_tr_runtime.append(mom_tr_2000['Runtime'].mean())
mom_tr_runtime.append(mom_tr_4000['Runtime'].mean())
mom_tr_runtime.append(mom_tr_8000['Runtime'].mean())
mom_tr_runtime.append(mom_tr_16000['Runtime'].mean())

mom_as_runtime.append(mom_as_1000['Runtime'].mean())
mom_as_runtime.append(mom_as_2000['Runtime'].mean())
mom_as_runtime.append(mom_as_4000['Runtime'].mean())
mom_as_runtime.append(mom_as_8000['Runtime'].mean())
mom_as_runtime.append(mom_as_16000['Runtime'].mean())

# These are your n values
n_values = [1000, 2000, 4000, 8000, 16000]

plt.figure(figsize=(10, 5))  # Optional: Adjusts the figure size

# Plotting both lists
plt.plot(n_values, mom_tr_runtime, label='Binary InsertionSort TR runtime', marker='o')  # 'o' adds markers to each point
plt.plot(n_values, mom_as_runtime, label='Binary InsertionSort AS runtime', marker='o')

# Adding titles and labels
plt.title('Simplified Timsort Runtimes, both True Random and Almost-sorted')
plt.xlabel('n')
plt.ylabel('Runtime')
plt.xticks(n_values, labels=[f'n = {val}' for val in n_values])  # Sets custom labels for the x-axis

# Adding a legend to explain which line is which
plt.legend()
plt.savefig("momrun.png")
# Display the plot
plt.show()

# %%
#Let's build the comparison table

# Creating the DataFrame, starting with Merge
tr_final = pd.DataFrame({
    "Algo": ["Merge"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": merge_tr_runtime
    })
tr_final['Ratio'] = tr_final['Observed Runtime'] / tr_final['Observed Runtime'].shift(1)
tr_final['Emp Big-O'] = np.log2(tr_final['Ratio'])

#Add Quick
tr_temp = pd.DataFrame({
    "Algo": ["Quick"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": quick_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add Insertion
tr_temp = pd.DataFrame({
    "Algo": ["Insertion"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": insertion_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add Shell1
tr_temp = pd.DataFrame({
    "Algo": ["Shell731"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": shell1_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add Shell2
tr_temp = pd.DataFrame({
    "Algo": ["Shell1000"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": shell2_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add Bucket
tr_temp = pd.DataFrame({
    "Algo": ["Bucket"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": bucket_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add Radix
tr_temp = pd.DataFrame({
    "Algo": ["Radix"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": radix_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add BinaryInsertionSort
tr_temp = pd.DataFrame({
    "Algo": ["Binary Insertion"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": bis_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

#Add Timsort
tr_temp = pd.DataFrame({
    "Algo": ["Simple Tim"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": mom_tr_runtime
})
tr_temp['Ratio'] = tr_temp['Observed Runtime'] / tr_temp['Observed Runtime'].shift(1)
tr_temp['Emp Big-O'] = np.log2(tr_temp['Ratio'])

tr_final = pd.concat([tr_final, tr_temp], ignore_index=True)

print(tr_final)
# Out:
#                 Algo  Data Size  Observed Runtime     Ratio  Emp Big-O
# 0              Merge       1000          0.001358       NaN        NaN
# 1              Merge       2000          0.002968  2.185281   1.127819
# 2              Merge       4000          0.006353  2.140799   1.098149
# 3              Merge       8000          0.013436  2.114739   1.080480
# 4              Merge      16000          0.028682  2.134772   1.094082
# 5              Quick       1000          0.000983       NaN        NaN
# 6              Quick       2000          0.002183  2.220533   1.150906
# 7              Quick       4000          0.004996  2.288156   1.194186
# 8              Quick       8000          0.012189  2.439670   1.286686
# 9              Quick      16000          0.031078  2.549712   1.350334
# 10         Insertion       1000          0.014235       NaN        NaN
# 11         Insertion       2000          0.059809  4.201434   2.070882
# ...

# %%
#Let's build the comparison table

# Creating the DataFrame, starting with Merge
as_final = pd.DataFrame({
    "Algo": ["Merge"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": merge_as_runtime
    })
as_final['Ratio'] = as_final['Observed Runtime'] / as_final['Observed Runtime'].shift(1)
as_final['Emp Big-O'] = np.log2(as_final['Ratio'])

#Add Quick
as_temp = pd.DataFrame({
    "Algo": ["Quick"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": quick_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add Insertion
as_temp = pd.DataFrame({
    "Algo": ["Insertion"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": insertion_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add Shell1
as_temp = pd.DataFrame({
    "Algo": ["Shell731"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": shell1_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add Shell2
as_temp = pd.DataFrame({
    "Algo": ["Shell1000"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": shell2_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add Bucket
as_temp = pd.DataFrame({
    "Algo": ["Bucket"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": bucket_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add Radix
as_temp = pd.DataFrame({
    "Algo": ["Radix"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": radix_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add BinaryInsertionSort
as_temp = pd.DataFrame({
    "Algo": ["Binary Insertion"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": bis_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

#Add Timsort
as_temp = pd.DataFrame({
    "Algo": ["Simple Tim"] * 5,
    "Data Size": [1000, 2000, 4000, 8000, 16000],
    "Observed Runtime": mom_as_runtime
})
as_temp['Ratio'] = as_temp['Observed Runtime'] / as_temp['Observed Runtime'].shift(1)
as_temp['Emp Big-O'] = np.log2(as_temp['Ratio'])

as_final = pd.concat([as_final, as_temp], ignore_index=True)

print(as_final)
# Out:
#                 Algo  Data Size  Observed Runtime     Ratio  Emp Big-O
# 0              Merge       1000          0.001372       NaN        NaN
# 1              Merge       2000          0.003013  2.196554   1.135242
# 2              Merge       4000          0.006403  2.125149   1.087564
# 3              Merge       8000          0.013497  2.107991   1.075869
# 4              Merge      16000          0.028850  2.137480   1.095911
# 5              Quick       1000          0.000985       NaN        NaN
# 6              Quick       2000          0.002114  2.146508   1.101992
# 7              Quick       4000          0.004996  2.363459   1.240900
# 8              Quick       8000          0.012218  2.445574   1.290173
# 9              Quick      16000          0.030703  2.512862   1.329332
# 10         Insertion       1000          0.014492       NaN        NaN
# 11         Insertion       2000          0.062298  4.298781   2.103928
# ...

# %%
#final outputs
tr_final.to_csv('tr_table.csv', index=False)
as_final.to_csv('as_table.csv', index=False)
